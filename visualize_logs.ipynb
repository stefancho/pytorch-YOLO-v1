# %%
import pandas as pd
from random import random
import matplotlib.pyplot as plt
from visualizer import Visualizer

# %%
vis = Visualizer(file_name='temp.csv')
vis.plot(['train_loss', 'val_loss'])
# Out:
# /home/stefan/projects/python/ML/pytorch-YOLO-v1/visualizer.py:16: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, index_col=self.index_column)

# %%
vis = Visualizer(file_name='train_log.csv')
vis.plot(['train_loss', 'val_loss'])
# Out:
# /home/stefan/projects/python/ML/pytorch-YOLO-v1/visualizer.py:16: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   df = pd.DataFrame.from_csv(filename, index_col=self.index_column)

# %%
vis = Visualizer()
vis.add_log(('val_loss', random()))
vis.save(file_name='test.csv')

# %%
vis = Visualizer(file_name='test.csv')

for i in range(5):
    vis.add_log(('val_loss', random()))

vis.add_log(('val_loss', random()))
    
    
for i in range(15):
    vis.add_log(('new', random()))


vis.plot()
vis._get_dataframe()
# Out:
# /home/stefan/projects/python/ML/pytorch-YOLO-v1/visualizer.py:12: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   self.dataframes = {}
#        val_loss       new
# epoch
# 1      0.310772  0.092209
# 2      0.242134  0.309471
# 3      0.119886  0.679552
# 4      0.722017  0.218703
# 5      0.950988  0.609074
# 6      0.666656  0.173609
# 7      0.425983  0.740614
# 8           NaN  0.186923
# 9           NaN  0.684175
# 10          NaN  0.960693
# 11          NaN  0.787751
# 12          NaN  0.156382
# 13          NaN  0.187308
# 14          NaN  0.139165
# 15          NaN  0.315023

# %%
dataframes['train_loss']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-04f3bc60e01e> in <module>()
# ----> 1 dataframes['train_loss']
#
# NameError: name 'dataframes' is not defined

# %%
df = vis.dataframes['train_loss']
df.loc[df['train_loss'] == 23]
# Out:
# Empty DataFrame
# Columns: [epoch, train_loss]
# Index: []

# %%
vis = Visualizer()

for i in range(3, 51):
    vis.add_log(("train_loss", random()), i)
# vis.add_log(4, ("train_loss", random()))   

for i in range(5, 50):
    vis.add_log(("val_loss", random()), i)

# vis.add_log(6, ("val_loss", 0.7))
    
for i in range(58):
    vis.add_log(("test_loss", random()), i)

# vis._get_dataframe().reset_index()

# vis._get_columns()

vis.plot()

# %%
df_list = [df.set_index('epoch') for df in vis.dataframes.values()]

pd.concat(df_list, axis=1)
# Out:
#        train_loss  val_loss  test_loss
# epoch
# 0             NaN       NaN   0.263292
# 1             NaN       NaN   0.361946
# 2             NaN       NaN   0.442193
# 3        0.805913       NaN   0.350145
# 4        0.326475       NaN   0.718833
# 5        0.144008  0.036870   0.309814
# 6        0.496563  0.520573   0.795918
# 7        0.068371  0.623106   0.440975
# 8        0.221684  0.087253   0.587486
# 9        0.508247  0.401369   0.262081
# 10       0.002123  0.487347   0.055132
# 11       0.041208  0.291778   0.818885
# 12       0.596407  0.719847   0.552517
# 13       0.671681  0.295175   0.704601
# 14       0.703141  0.473123   0.490932
# 15       0.741985  0.939783   0.827743
# 16       0.818840  0.741614   0.805734
# 17       0.109307  0.197653   0.154014
# 18       0.661405  0.613629   0.646671
# 19       0.409854  0.999023   0.126641
# 20       0.405401  0.868914   0.905529
# 21       0.482289  0.496611   0.853491
# 22       0.102768  0.985402   0.269036
# ...

# %%
df1 = vis.dataframes['train_loss'].set_index('epoch')
df2 = vis.dataframes['val_loss'].set_index('epoch')
df3 = vis.dataframes['test_loss'].set_index('epoch')

# %%
df1.join(df2, how='inner')
# Out:
#        train_loss  val_loss
# epoch
# 5        0.144008  0.036870
# 6        0.496563  0.520573
# 7        0.068371  0.623106
# 8        0.221684  0.087253
# 9        0.508247  0.401369
# 10       0.002123  0.487347
# 11       0.041208  0.291778
# 12       0.596407  0.719847
# 13       0.671681  0.295175
# 14       0.703141  0.473123
# 15       0.741985  0.939783
# 16       0.818840  0.741614
# 17       0.109307  0.197653
# 18       0.661405  0.613629
# 19       0.409854  0.999023
# 20       0.405401  0.868914
# 21       0.482289  0.496611
# 22       0.102768  0.985402
# 23       0.690529  0.259950
# 24       0.760309  0.426983
# 25       0.745270  0.536525
# 26       0.012636  0.396089
# 27       0.016722  0.668083
# 28       0.750028  0.153635
# 29       0.709642  0.474029
# 30       0.098955  0.144229
# 31       0.667800  0.522294
# 32       0.589947  0.101053
# 33       0.591167  0.171559
# 34       0.825200  0.002266
# 35       0.570425  0.385010
# 36       0.188592  0.072498
# ...

# %%
pd.concat(vis.dataframes.values(), axis=1)
# Out:
#    epoch  train_loss  epoch  val_loss  epoch  test_loss
# 0      0    0.022463      0  0.305445      0   0.404812
# 0      1    0.600136      1  0.975016      1   0.831108
# 0      2    0.099959      2  0.489317      2   0.745201
# 0      3    0.081297      3  0.987953      3   0.403647
# 0      4    0.771242      4  0.246823      4   0.610236
# 0      5    0.210865      5  0.528313      5   0.395523
# 0      6    0.853024      6  0.132581      6   0.894980
# 0      7    0.265787      7  0.466136      7   0.053488
# 0      8    0.124733      8  0.346678      8   0.164234
# 0      9    0.056793      9  0.227268      9   0.448539
